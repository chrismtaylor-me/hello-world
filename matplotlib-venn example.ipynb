# %%
from matplotlib_venn import venn3
venn3(subsets = (1, 2, 3, 4, 5, 6, 7), 
      set_labels = ('set A', 'set B', 'set C'))

# %%
from matplotlib_venn import venn3
venn3(subsets = (10, 2, 3, 4, 5, 0, 0), 
      set_labels = ('set A', 'set B', 'set C'))
